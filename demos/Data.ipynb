# %%
from pandas import DataFrame

# %%
from jupyter_helpers.selective_import import skip_on_import

# %%
data = DataFrame({'observations': [1, 2, 2.6, 3, 3]})

# %%
# %%skip_on_import
# # some "costly" QC or visualisation of the data
# vis = data.hist()
